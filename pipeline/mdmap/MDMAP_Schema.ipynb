# %%
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv('RawStandingStockReport.csv')

# %%
raw_data.head()
# Out:
#       Survey Type                                  Organization        Date  \
# 0  Standing-Stock  Clean Virginia Waterways/Longwood University  09-19-2016
# 1  Standing-Stock  Clean Virginia Waterways/Longwood University  09-19-2016
# 2  Standing-Stock  Clean Virginia Waterways/Longwood University  09-19-2016
# 3  Standing-Stock  Clean Virginia Waterways/Longwood University  09-19-2016
# 4  Standing-Stock  Clean Virginia Waterways/Longwood University  09-28-2016
#
#   Survey Year        Country State    County  Survey ID  MDMAP ID #  \
# 0      Year 3  United States    VA  VA Beach       6072         164
# 1      Year 3  United States    VA  VA Beach       6073         164
# 2      Year 3  United States    VA  VA Beach       6074         164
# 3      Year 3  United States    VA  VA Beach       6075         164
# 4      Year 3  United States    VA  Accomack       6185         170
#
#    Transect ID  ... Cloth/Fabric  Clothing & Shoes  Gloves (non-rubber)  \
# ...

# %%
raw_data.columns
# Out:
# Index(['Survey Type', 'Organization', 'Date', 'Survey Year', 'Country',
#        'State', 'County', 'Survey ID', 'MDMAP ID #', 'Transect ID',
#        'Shoreline Name', 'Latitude Start', 'Longitude Start', 'Latitude End',
#        'Longitude End', 'Slope', 'Width', 'Length', 'Start Time', 'End Time',
#        'Time of Low Tide', 'Database Season', 'Season', 'Storm Activity',
#        'Current Weather', 'Number of Persons Assisting', 'Large Items?',
#        'Debris Behind Back Barrier?', 'Datasheet Version', 'Notes', 'Photos?',
#        'Plastic', 'Hard Plastic Fragments', 'Foamed Plastic Fragments',
#        'Filmed Plastic Fragments', 'Food Wrappers', 'Plastic Beverage Bottles',
#        'Other Jugs/Containers', 'Bottle/Container Caps', 'Cigar Tips',
#        'Cigarettes', 'Disposable Cigarette Lighters', '6-Pack Rings', 'Bags',
#        'Plastic Rope/Net', 'Buoys & Floats', 'Fishing Lures & Line', 'Cups',
#        'Plastic Utensils', 'Straws', 'Balloons Mylar',
# ...

# %%
OCPDS = pd.read_csv('Ocean_Plastics_dataset_schemas.csv')

# %%
OCPDS.head()
# Out:
#   These are the columns we want in the final files (i.e. the output of each script).  \
# 0                                                NaN
# 1                                        Column name
# 2                                                  X
# 3                                                  Y
# 4                                                FID
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                        Description
# 2                                          Longitude
# 3                                           Latitude
# 4  Feature ID defined by ArcGIS (once compiled, A...

# %%
OCPDS.iloc[2:,:1]
# Out:
#    These are the columns we want in the final files (i.e. the output of each script).
# 2                                                   X
# 3                                                   Y
# 4                                                 FID
# 5                                    RecordSequenceID
# 6                                            UniqueID
# ..                                                ...
# 80                                             Count_
# 81                                        Soft_sheets
# 82                              Other_StrapsTiesBands
# 83                                   Other_Glowsticks
# 84                                       OtherFishing
#
# [83 rows x 1 columns]

# %%
#dropping columns, how to rename them?
OCPDS = OCPDS.drop(['Unnamed: 1'], axis=1)
OCPDS.head()
# Out:
#   These are the columns we want in the final files (i.e. the output of each script).
# 0                                                NaN
# 1                                        Column name
# 2                                                  X
# 3                                                  Y
# 4                                                FID

# %%
OCPDS_columns = OCPDS.loc[2]
OCPDS_columns
#OCPDS_column_names = OCPDS[2:]
# Out:
# These are the columns we want in the final files (i.e. the output of each script).    X
# Name: 2, dtype: object

# %%
help()

# %%
OCPDS[1:]
# Out:
#    These are the columns we want in the final files (i.e. the output of each script).  \
# 1                                         Column name
# 2                                                   X
# 3                                                   Y
# 4                                                 FID
# 5                                    RecordSequenceID
# ..                                                ...
# 80                                             Count_
# 81                                        Soft_sheets
# 82                              Other_StrapsTiesBands
# 83                                   Other_Glowsticks
# 84                                       OtherFishing
#
#                                            Unnamed: 1
# 1                                         Description
# 2                                           Longitude
# 3                                            Latitude
# 4   Feature ID defined by ArcGIS (once compiled, A...
# ...

# %%
OCPDS[]
# Out:
#   File "<ipython-input-15-f81984ca8d1f>", line 1
#     OCPDS[]
#           ^
# SyntaxError: invalid syntax

# %%
column_names = ['X','Y','FID'']

# %%
df1 = ['X','Y',]

# %% [markdown]
# #indexing using pandas,
# df.iloc[:,33]
